# %%
import pandas as pd
import numpy as np
import random

# %%
names = pd.read_csv('initial_babynames.csv', sep=',')
   
my_randoms=[]    
for i in range (len(names.name)):    
    my_randoms.append(random.randrange(10,99,1))    
    
names['Age'] = my_randoms
names = names.drop(['percent', 'year'], axis = 1)
names['sex'] = names['sex'].replace("boy", "male")
names['sex'] = names['sex'].replace("girl", "female")
head = names.sample(frac=1).head(10000)

# %%
names.to_csv("database.csv")
names.to_json("database.json", orient = 'index')
head.to_csv("short_data.csv")
head.to_json("short_data.json", orient = 'records')

# %%
head[head.sex == 'female']
# Out:
#              name     sex  Age
# 135720      Nella  female   13
# 178171   Jeannine  female   51
# 172788      Sonia  female   89
# 140192     Virgie  female   57
# 151181       Elva  female   60
# 131725    Rachael  female   22
# 179153      Rosie  female   75
# 162514    Suzanne  female   84
# 143891       Osie  female   37
# 133348      Angie  female   11
# 129758     Cherry  female   33
# 170387    Cynthia  female   96
# 175991    Lurline  female   53
# 179903       Lyda  female   90
# 180061    Lucille  female   85
# 166216       Alta  female   14
# 155141    Barbara  female   91
# 165355   Gretchen  female   77
# 133211       Leah  female   35
# 180600       Gene  female   77
# 167780       Ines  female   24
# 172020     Martha  female   90
# 167366    Pearlie  female   33
# 179943   Jeanetta  female   84
# 173875       Viva  female   15
# 148384       Mona  female   92
# 162173       Nina  female   48
# 145903      Alyce  female   65
# 168259    Eugenia  female   98
# 179081   Rosemary  female   55
# ...           ...     ...  ...
# 162528     Dortha  female   97
# 182066      Clara  female   89
# 152270       Nola  female   90
# 141049        Ada  female   87
# 140422      Eddie  female   97
# 142514      Ferne  female   11
# 179198  Gwendolyn  female   54
# 148005   Florence  female   79
# 175879      Ellie  female   94
# 132323     Adelia  female   23
# 143721      Eulah  female   52
# 148925     Maymie  female   78
# 172684     Lavina  female   29
# 139643  Celestine  female   88
# 149552      Minna  female   46
# 160322     Aileen  female   67
# 133356       Vida  female   59
# 155678     Dortha  female   62
# 162006       Anna  female   39
# 129870  Gwendolyn  female   54
# 141930      Gusta  female   75
# 182799    Rosanne  female   46
# 179368    Loraine  female   31
# 181890   Beverlee  female   13
# 133101    Rebecca  female   64
# 140946      Attie  female   31
# 160102      Emily  female   24
# 147557      Berta  female   45
# 178763        Ana  female   43
# 155376  Elisabeth  female   70
#
# [29666 rows x 3 columns]
